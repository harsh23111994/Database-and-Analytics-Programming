# %%
#Connect to Postgres
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "postgres")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    #dbCursor.execute('CREATE DATABASE DAP;')
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#Creating table deaths 
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
        CREATE TABLE deaths(
        age_adjusted_death_rate numeric(8,2),
        death_rate numeric(8,2),
        deaths numeric(5,1),
        leading_cause varchar(255),
        race_ethnicity varchar(255),
        sex varchar(255),
        year int
        );
    """)
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#Insert values in deaths
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/Harsh_data.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader) # skip the header
        for row in reader:
            dbCursor.execute("INSERT INTO deaths VALUES (%s,%s,%s,%s,%s,%s,%s)",row)
    dbConnection.commit()    
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
# Creating Tables Shooting
try:
    dbConnection = psycopg2.connect(
    user = "dap",
    password = "dap",
    host = "192.168.56.30",
    port = "5432",
    database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
    CREATE TABLE shoot(
        boro varchar(255),
        precinct numeric(8,2),
        jurisdiction_code numeric(5,1),
        statistical_murder_flag bool,
        vice_age_group numeric(5,1),
        vice_sex varchar(255),
        vice_race varchar(255),
        location_desc varchar(255),
        perp_age_group numeric(5,1),
        perp_sex varchar(255),
        perp_race varchar(255),
        shooting_hour int,
        year int,
        Day int
        );
    """)
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
# Inserting values in shoot
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/vijit_data.csv', 'r') as f:
        read = csv.reader(f)
        next(read)
        for row in read:
            dbCursor.execute("INSERT INTO shoot VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",row)
        dbConnection.commit() 
        
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
# Creating Table Criminal Court
try:
    dbConnection = psycopg2.connect(
    user = "dap",
    password = "dap",
    host = "192.168.56.30",
    port = "5432",
    database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
    CREATE TABLE crimes(
        
        age_group VARCHAR(255),
        boro VARCHAR(255),
        law_description VARCHAR(255),           
        law_section_number VARCHAR(255),       
        offense_description VARCHAR(255),      
        precinct_of_occur  INT,
        race VARCHAR(255),
        sex VARCHAR(255),
        summons_category_type VARCHAR(255), 
        summons_date date,
        summons_key INT PRIMARY KEY
    );
    """)
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
# Inserting vales to Criminal Court
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/imran_data.csv', 'r') as f:
        read = csv.reader(f)
        next(read)
        #dbCursor.copy_from(f, 'criminalcourts5', sep=',')
        for row in read:
            dbCursor.execute("INSERT INTO crimes VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",row)
        dbConnection.commit() 
        
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#create table Drug death cause
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
        CREATE TABLE drug(
        age int,
        benzodiazepine TEXT,
        cocaine TEXT,
        date  timestamp,
        datetype  TEXT,
        deathcity TEXT,
        ethanol TEXT,
        fentanyl TEXT,
        heroin   TEXT,
        id varchar(255) PRIMARY KEY NOT NULL,
        location  TEXT,
        mannerofdeath TEXT,
        methadone TEXT,
        oxycodone TEXT,
        race TEXT,
        sex TEXT,
        year int 
        
        );
        """)
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#insert Vales in drug
import psycopg2
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/dev_data.csv', 'r') as f:
        read = csv.reader(f)
        next(read)
        for row in read:
            dbCursor.execute("INSERT INTO drug VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",row)
        dbConnection.commit() 
        
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#Complex Query 2
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2
sql = """
select COUNT(d.deaths),d.race_ethnicity,c.boro  
From deaths AS d 
INNER JOIN crimes as c 
ON (LOWER(d.race_ethnicity) = LOWER(c.race) )
GROUP BY (d.race_ethnicity,c.boro)
ORDER BY c.boro ASC;
"""
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    test = sqlio.read_sql_query(sql, dbConnection)
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#Complex Query 1 Db
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
        CREATE TABLE Q1(
        count int,
        race VARCHAR(255),
        boro VARCHAR(255));
        """)
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
export_csv = test.to_csv(r'C:\Users\Harsh\Desktop\NCI\Database and Analytics Programming\DAP Project\Q1.csv', index = None,encoding="UTF-8", header=True)

# %%
#insert Vales in Q1
import psycopg2
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/Q1.csv', 'r') as f:
        read = csv.reader(f)
        next(read)
        for row in read:
            dbCursor.execute("INSERT INTO q1 VALUES (%s,%s,%s)",row)
        dbConnection.commit() 
        
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
test
# Out:
#    count  race_ethnicity           boro
# 0  10126  Black Hispanic          BRONX
# 1  15015  White Hispanic          BRONX
# 2   2490  Black Hispanic       BROOKLYN
# 3   8250  White Hispanic       BROOKLYN
# 4   2988  Black Hispanic       NEW YORK
# 5  11880  White Hispanic       NEW YORK
# 6    498  Black Hispanic         QUEENS
# 7   6765  White Hispanic         QUEENS
# 8    660  White Hispanic  STATEN ISLAND

# %%
#Complex Query 2 
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2
sql = """ 
SELECT AVG(drug.age),deaths.sex,drug.cocaine,drug.location
FROM deaths 
INNER JOIN drug  ON deaths.year = drug.year WHERE drug.cocaine LIKE 'Y'
GROUP BY drug.cocaine,deaths.sex,drug.age,drug.location;
"""
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    test2 = sqlio.read_sql_query(sql, dbConnection)
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#Complex Query 2 DB
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
        CREATE TABLE Q2(
        age numeric(8,2),
        sex VARCHAR(255),
        cocaine VARCHAR(255),
        boro VARCHAR(255));
        """)
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
export_csv = test2.to_csv(r'C:\Users\Harsh\Desktop\NCI\Database and Analytics Programming\DAP Project\Q2.csv', index = None,encoding="UTF-8", header=True)

# %%
#insert Vales in Q2
import psycopg2
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/Q2.csv', 'r') as f:
        read = csv.reader(f)
        next(read)
        for row in read:
            dbCursor.execute("INSERT INTO q2 VALUES (%s,%s,%s,%s)",row)
        dbConnection.commit() 
        
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
test2
# Out:
#      avg     sex cocaine   location
# 0   43.0  Female       Y      Other
# 1   35.0  Female       Y      Other
# 2   59.0  Female       Y  Residence
# 3   44.0    Male       Y   Hospital
# 4   56.0    Male       Y  Residence
# 5   39.0  Female       Y   Hospital
# 6   44.0    Male       Y      Other
# 7   43.0  Female       Y  Residence
# 8   28.0  Female       Y  Residence
# 9   27.0    Male       Y   Hospital
# 10  44.0  Female       Y      Other
# 11  34.0  Female       Y   Hospital
# 12  30.0    Male       Y  Residence
# 13  35.0    Male       Y      Other
# 14  46.0    Male       Y  Residence
# 15  26.0    Male       Y      Other
# 16  34.0    Male       Y   Hospital
# 17  43.0  Female       Y   Hospital
# 18  54.0    Male       Y  Residence
# 19  49.0    Male       Y  Residence
# 20  21.0    Male       Y   Hospital
# 21  60.0    Male       Y   Hospital
# 22  59.0    Male       Y  Residence
# 23  35.0  Female       Y  Residence
# 24  53.0    Male       Y  Residence
# ...

# %%
test2
# Out:
#      avg     sex cocaine   location
# 0   43.0  Female       Y      Other
# 1   35.0  Female       Y      Other
# 2   59.0  Female       Y  Residence
# 3   44.0    Male       Y   Hospital
# 4   56.0    Male       Y  Residence
# 5   39.0  Female       Y   Hospital
# 6   44.0    Male       Y      Other
# 7   43.0  Female       Y  Residence
# 8   28.0  Female       Y  Residence
# 9   27.0    Male       Y   Hospital
# 10  44.0  Female       Y      Other
# 11  34.0  Female       Y   Hospital
# 12  30.0    Male       Y  Residence
# 13  35.0    Male       Y      Other
# 14  46.0    Male       Y  Residence
# 15  26.0    Male       Y      Other
# 16  34.0    Male       Y   Hospital
# 17  43.0  Female       Y   Hospital
# 18  54.0    Male       Y  Residence
# 19  49.0    Male       Y  Residence
# 20  21.0    Male       Y   Hospital
# 21  60.0    Male       Y   Hospital
# 22  59.0    Male       Y  Residence
# 23  35.0  Female       Y  Residence
# 24  53.0    Male       Y  Residence
# ...

# %%
#Complex Query 3
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2
sql = """ 
SELECT MAX(drug.age),COUNT(distinct deaths.deaths),drug.sex
FROM deaths
INNER JOIN crimes  ON LOWER(deaths.race_ethnicity) = LOWER(crimes.race)
INNER JOIN shoot  ON LOWER(shoot.boro) = LOWER(crimes.boro)
INNER JOIN drug  ON LOWER(shoot.perp_sex) = LOWER(drug.sex)
GROUP BY shoot.boro,crimes.race,drug.sex,shoot.precinct;
"""
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    test3 = sqlio.read_sql_query(sql, dbConnection)
except (Exception , psycopg2.Error) as db\
Error :
    print ("Error:", dbError) 
finally:
    if(dbConnection): dbConnection.close()
# Out:
# Error: Execution failed on sql '
# SELECT MAX(drug.age),COUNT(distinct deaths.deaths),drug.sex
# FROM deaths
# INNER JOIN crimes  ON LOWER(deaths.race_ethnicity) = LOWER(crimes.race)
# INNER JOIN shoot  ON LOWER(shoot.boro) = LOWER(crimes.boro)
# INNER JOIN drug  ON LOWER(shoot.perp_sex) = LOWER(drug.sex)
# GROUP BY shoot.boro,crimes.race,drug.sex,shoot.precinct;
# ': could not write block 1777574 of temporary file: No space left on device

# %%
#Complex Query 3
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2
sql = """ 
SELECT shoot.shooting_hour, shoot.location_desc,crimes.boro, drug.sex 
FROM drug
INNER JOIN shoot  ON drug.year = shoot.year
INNER JOIN crimes  ON LOWER(shoot.boro) = LOWER(crimes.boro)
GROUP BY shoot.location_desc,drug.sex,crimes.boro,shoot.shooting_hour
ORDER BY crimes.boro;
"""
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    test4 = sqlio.read_sql_query(sql, dbConnection)
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
#Complex Query 3 DB
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute("""
        CREATE TABLE Q3(
        hour int,
        location VARCHAR(255),
        boro VARCHAR(255),
        sex VARCHAR(255));
        """)
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
export_csv = test4.to_csv(r'C:\Users\Harsh\Desktop\NCI\Database and Analytics Programming\DAP Project\Q3.csv', index = None,encoding="UTF-8", header=True)

# %%
#insert Vales in Q3
import psycopg2
import csv
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "192.168.56.30",
        port = "5432",
        database = "dap")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    with open('C:/Users/Harsh/Desktop/NCI/Database and Analytics Programming/DAP Project/Q3.csv', 'r') as f:
        read = csv.reader(f)
        next(read)
        for row in read:
            dbCursor.execute("INSERT INTO q3 VALUES (%s,%s,%s,%s)",row)
        dbConnection.commit() 
        
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error:", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
test4
# Out:
#      shooting_hour       location_desc           boro     sex
# 0               23      BAR/NIGHT CLUB          BRONX  Female
# 1               22        PUBLIC HOUSE          BRONX    Male
# 2               15        PUBLIC HOUSE          BRONX  Female
# 3                1           APT BUILD          BRONX    Male
# 4               22           APT BUILD          BRONX    Male
# 5               17        PUBLIC HOUSE          BRONX  Female
# 6               23     COMMERCIAL BLDG          BRONX    Male
# 7               21      BAR/NIGHT CLUB          BRONX    Male
# 8                2        PUBLIC HOUSE          BRONX  Female
# 9               22     COMMERCIAL BLDG          BRONX    Male
# 10               3        PUBLIC HOUSE          BRONX    Male
# 11               3           APT BUILD          BRONX    Male
# 12              23        PUBLIC HOUSE          BRONX  Female
# 13               7           APT BUILD          BRONX  Female
# ...
